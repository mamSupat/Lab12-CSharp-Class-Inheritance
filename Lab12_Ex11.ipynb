// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// # Lab 8 Exercise 8

// %% [markdown]
// ## Masking base class member with `new` keyword

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex11
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// System.Console.WriteLine(dc.Hello);
//
// class BaseClass
// {
//     public string Hello = "Hello From BaseClass";
// }
// class DerivedClass : BaseClass
// {
//     new public string Hello = "Hello From DerivedClass";
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex11
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![19.png](attachment:19.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex11
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![20.png](attachment:20.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// มีการใช้ new ในการประกาศฟิลด์ Hello ใน DerivedClass เป็นการซ่อนฟิลด์ Hello ใน BaseClass
//
// เมื่อเรียก dc.Hello จะได้รับค่าจากฟิลด์ Hello ของ DerivedClass เนื่องจาก dc เป็นอ็อบเจกต์ของ DerivedClass

// %% [markdown]
// ### คำถาม

// %% [markdown]
// 1. ถ้ารันคำสั่ง Console.WriteLine((dc as BaseClass).Hello); จะแสดงผลว่าอย่างไร

// %% [markdown]
// ได้ผลลัพธ์ Hello From BaseClass

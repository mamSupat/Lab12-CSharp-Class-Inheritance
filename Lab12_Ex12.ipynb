// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Access base member by `base` keyword

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex12
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```cs
// DerivedClass dc = new DerivedClass();
// dc.PrintBaseHello();
//
// class BaseClass
// {
//     public string Hello = "Hello From BaseClass";
// }
// class DerivedClass : BaseClass
// {
//     new public string Hello = "Hello From DerivedClass";
//
//     public void PrintBaseHello()
//     {
//         string BaseHello = base.Hello;       // ใช้งานสมาชิกใน base class โดยคีย์เวิร์ด base
//         System.Console.WriteLine(BaseHello);
//     }
// }
//
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex12
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![21.png](attachment:21.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex12
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![22.png](attachment:22.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// BaseClass : มีฟิลด์ Hello ที่มีค่าเป็น "Hello From BaseClass"
//
// DerivedClass : ซ่อนฟิลด์ Hello ของ BaseClass ด้วยคำสั่ง new และมีค่าเป็น "Hello From DerivedClass" และมีเมธอด PrintBaseHello() ที่ใช้คีย์เวิร์ด base เพื่อเข้าถึงฟิลด์ Hello ของ BaseClass

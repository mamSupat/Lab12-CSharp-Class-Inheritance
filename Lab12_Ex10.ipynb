// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Access overriding base class member (Methods)

// %% [markdown]
// การเข้าถึงสมาชิกของ Base class ที่ถูกปิดบัง ทำได้โดยการแปลงชนิดข้อมูลไปยัง BaseClass เสียก่อน แล้วจึงเข้าถึงสมาชิกที่สืบทอดมาจาก base class นั้น

// %% [markdown]
// สามารถทำได้ 2 แบบ คือ
//
// 1. ใช้วิธีการแปลงประเภท (Type Casting) หรือ การแปลงชนิดข้อมูล (Data Type Conversion)
//
// 2. ใช้ keyword `'as'`

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex10
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// // 1. ใช้วิธีการแปลงประเภท (Type Casting) หรือ การแปลงชนิดข้อมูล (Data Type Conversion)
// DerivedClass dc = new DerivedClass();
// Console.WriteLine("Use Type Casting or Data Type Conversion");
// ((BaseClass)dc).Greeting();
//
// // 2. ใช้ keyword 'as'
// Console.WriteLine("------------");
// Console.WriteLine("Use as keyword");
// (dc as BaseClass).Greeting();
//
// class BaseClass
// {
//     public string Hello = "Hello From BaseClass";
//     public void Greeting()
//     {
//         Console.WriteLine("This is method in BaseClass");
//         Console.WriteLine(Hello);
//     }
//
// }
// class DerivedClass : BaseClass
// {
//     public string Hello = "Hello From DerivedClass";
//     public void Greeting()
//     {
//         Console.WriteLine("This is method in DerivedClass");
//         Console.WriteLine(Hello);
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex10
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![17.png](attachment:17.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex10
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![18.png](attachment:18.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// เมื่อใช้ ((BaseClass)dc) เพื่อแปลง dc จาก DerivedClass เป็น BaseClass, จะเรียกเมธอด Greeting() ของ BaseClass ดังนั้นจะได้ข้อความ "This is method in BaseClass" และค่าของ Hello จาก BaseClass, คือ "Hello From BaseClass"
//
// เมื่อใช้ (dc as BaseClass) ผลลัพธ์จะเหมือนกันกับ Type Casting เพราะ dc เป็นอ็อบเจกต์ที่สืบทอดจาก BaseClass การแปลงนี้จะไม่ทำให้เกิดข้อผิดพลาดแม้ว่า as จะสามารถคืนค่า null หากแปลงไม่ได้ แต่ในกรณีนี้เราได้รับเมธอด Greeting() จาก BaseClass.

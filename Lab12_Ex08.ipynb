// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Overriding base class member (Variables)

// %% [markdown]
// การสร้างสมาชิกใหม่ขึ้นใน Derived class โดยใช้ signature เดียวกับสมาชิกใน Base class เรียกว่าการ overriding

// %% [markdown]
// สามารถ Overriding ได้ทั้ง variables และ methods

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex08
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// System.Console.WriteLine(dc.Hello);
//
// class BaseClass
// {
//     public string Hello = "Hello From BaseClass";
// }
// class DerivedClass : BaseClass
// {
//     public string Hello = "Hello From DerivedClass";
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex08
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![13.png](attachment:13.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex08
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![14.png](attachment:14.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ฟิลด์ Hello ใน DerivedClass ซ่อนฟิลด์ Hello ใน BaseClass
//
// เมื่อเข้าถึง Hello จาก dc ซึ่งเป็นอ็อบเจกต์ของ DerivedClass, จะได้ผลลัพธ์จาก DerivedClass
//
// หากต้องการเข้าถึงฟิลด์ใน BaseClass สามารถทำได้โดยใช้การแคสต์ (casting) หรือใช้ base.Hello
